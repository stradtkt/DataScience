# %% [markdown]
# Pandas Practice

# %%
import pandas as pd
import numpy as np
exam_data = {"name": ['Kevin', 'John', 'Mike', 'Eric', 'Patrick', 'Kyle', 'Brandon', 'Jose', 'Debra', 'Katie'],
             "score": [12.5, 9, 16.5, np.NaN, 9, 20, 14.5, np.NaN, 8, 19],
             "attempts": [1,3,2,3,2,3,1,1,2,1],
             "qualify": ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(exam_data, index=labels)
df
# Out:
#       name  score  attempts qualify
# a    Kevin   12.5         1     yes
# b     John    9.0         3      no
# c     Mike   16.5         2     yes
# d     Eric    NaN         3      no
# e  Patrick    9.0         2      no
# f     Kyle   20.0         3     yes
# g  Brandon   14.5         1     yes
# h     Jose    NaN         1      no
# i    Debra    8.0         2      no
# j    Katie   19.0         1     yes

# %%
mean = df['score'].mean()
mean
# Out:
# 13.5625

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('grades.csv')
df.head(15)
# Out:
#     id               name                         email  Exams  Tests  \
# 0    1         Carl Bosch              cbosch0@yelp.com  70.24  64.14
# 1    2   Philis Hoodspeth       phoodspeth1@foxnews.com  97.04  74.78
# 2    3   Nicholas Kemmett            nkemmett2@youtu.be  98.71  72.52
# 3    4      Kerri Chitson  kchitson3@huffingtonpost.com  94.64  98.53
# 4    5    Hans Silverwood         hsilverwood4@narod.ru  73.77  72.77
# 5    6         Rasia Anan         ranan5@deviantart.com  77.23  70.47
# 6    7     Marne Greenley         mgreenley6@unicef.org  60.09  68.63
# 7    8     Marius Sanches        msanches7@redcross.org  88.81  66.88
# 8    9     Ermin Fairpool      efairpool8@blinklist.com  81.61  71.19
# 9   10  Chrotoem Boustred         cboustred9@uol.com.br  70.32  79.77
# 10  11      Jenine Sokell   jsokella@huffingtonpost.com  74.22  93.98
# 11  12     Cirilo Brizell             cbrizellb@ask.com  92.49  70.76
# ...

# %%
df['Average'] = (df['Exams'] + df['Tests'] + df['Projects'] + df['Home Work'])/4
df.sort_values(['Average'], ascending=[False], inplace=True)
df.head(15)
# Out:
#       id               name                          email  Exams  Tests  \
# 203  204     Alysia Drummer            adrummer5n@ucoz.com  93.24  88.74
# 3      4      Kerri Chitson   kchitson3@huffingtonpost.com  94.64  98.53
# 164  165        Barry Simla            bsimla4k@dyndns.org  97.14  90.83
# 18    19    Jarrod Lashford           jlashfordi@wufoo.com  98.23  89.46
# 142  143    Guillaume Slate              gslate3y@jugem.jp  86.76  94.50
# 157  158     Matilde Burden  mburden4d@creativecommons.org  95.49  77.40
# 188  189    Aristotle Petel          apetel58@hubpages.com  74.74  94.60
# 66    67      Lazaro Hought        lhought1u@tuttocitta.it  92.14  98.79
# 244  245  Chauncey Parysiak   cparysiak6s@businesswire.com  98.88  78.40
# 206  207      Fianna Chance      fchance5q@theguardian.com  96.02  96.06
# 48    49      Gail Mallinar       gmallinar1c@bluehost.com  92.43  90.42
# 247  248     Silvanus Rehor           srehor6v@behance.net  96.17  78.05
# ...

# %%
df.rename(columns = {"name": "Name"})
df.head(10)
# Out:
#       id               name                          email  Exams  Tests  \
# 203  204     Alysia Drummer            adrummer5n@ucoz.com  93.24  88.74
# 3      4      Kerri Chitson   kchitson3@huffingtonpost.com  94.64  98.53
# 164  165        Barry Simla            bsimla4k@dyndns.org  97.14  90.83
# 18    19    Jarrod Lashford           jlashfordi@wufoo.com  98.23  89.46
# 142  143    Guillaume Slate              gslate3y@jugem.jp  86.76  94.50
# 157  158     Matilde Burden  mburden4d@creativecommons.org  95.49  77.40
# 188  189    Aristotle Petel          apetel58@hubpages.com  74.74  94.60
# 66    67      Lazaro Hought        lhought1u@tuttocitta.it  92.14  98.79
# 244  245  Chauncey Parysiak   cparysiak6s@businesswire.com  98.88  78.40
# 206  207      Fianna Chance      fchance5q@theguardian.com  96.02  96.06
#
#      Projects  Home Work  Average
# 203     98.20      88.34  92.1300
# 3       80.78      92.20  91.5375
# 164     83.32      93.94  91.3075
# ...

# %%
df.rename(columns = {"email": "Email"})
df.head(10)
# Out:
#       id               name                          email  Exams  Tests  \
# 203  204     Alysia Drummer            adrummer5n@ucoz.com  93.24  88.74
# 3      4      Kerri Chitson   kchitson3@huffingtonpost.com  94.64  98.53
# 164  165        Barry Simla            bsimla4k@dyndns.org  97.14  90.83
# 18    19    Jarrod Lashford           jlashfordi@wufoo.com  98.23  89.46
# 142  143    Guillaume Slate              gslate3y@jugem.jp  86.76  94.50
# 157  158     Matilde Burden  mburden4d@creativecommons.org  95.49  77.40
# 188  189    Aristotle Petel          apetel58@hubpages.com  74.74  94.60
# 66    67      Lazaro Hought        lhought1u@tuttocitta.it  92.14  98.79
# 244  245  Chauncey Parysiak   cparysiak6s@businesswire.com  98.88  78.40
# 206  207      Fianna Chance      fchance5q@theguardian.com  96.02  96.06
#
#      Projects  Home Work  Average
# 203     98.20      88.34  92.1300
# 3       80.78      92.20  91.5375
# 164     83.32      93.94  91.3075
# ...

# %%
df.iloc[10:20]
# Out:
#       id              name                      email  Exams  Tests  Projects  \
# 48    49     Gail Mallinar   gmallinar1c@bluehost.com  92.43  90.42     98.46
# 247  248    Silvanus Rehor       srehor6v@behance.net  96.17  78.05     84.63
# 170  171   Lizette Coulsen       lcoulsen4q@google.fr  79.06  98.49     88.91
# 205  206  Franklyn Shooter          fshooter5p@un.org  84.81  98.70     87.00
# 232  233    Kizzie Gerwood    kgerwood6g@sakura.ne.jp  96.19  83.54     96.44
# 47    48   Jaquelin Cuerda        jcuerda1b@wiley.com  94.20  94.21     70.23
# 171  172       Syd Cocklie      scocklie4r@ebay.co.uk  84.76  96.94     89.22
# 16    17       Daryl Huish      dhuishg@aboutads.info  97.10  99.28     88.39
# 42    43     Juana Rozzier      jrozzier16@census.gov  98.95  85.10     73.44
# 68    69      Hans Simacek  hsimacek1w@altervista.org  88.24  86.48     83.19
#
#      Home Work  Average
# 48       76.57  89.4700
# 247      98.55  89.3500
# 170      90.06  89.1300
# ...

# %%
df.drop(columns=['id'])
df.head(10)
# Out:
#       id               name                          email  Exams  Tests  \
# 203  204     Alysia Drummer            adrummer5n@ucoz.com  93.24  88.74
# 3      4      Kerri Chitson   kchitson3@huffingtonpost.com  94.64  98.53
# 164  165        Barry Simla            bsimla4k@dyndns.org  97.14  90.83
# 18    19    Jarrod Lashford           jlashfordi@wufoo.com  98.23  89.46
# 142  143    Guillaume Slate              gslate3y@jugem.jp  86.76  94.50
# 157  158     Matilde Burden  mburden4d@creativecommons.org  95.49  77.40
# 188  189    Aristotle Petel          apetel58@hubpages.com  74.74  94.60
# 66    67      Lazaro Hought        lhought1u@tuttocitta.it  92.14  98.79
# 244  245  Chauncey Parysiak   cparysiak6s@businesswire.com  98.88  78.40
# 206  207      Fianna Chance      fchance5q@theguardian.com  96.02  96.06
#
#      Projects  Home Work  Average
# 203     98.20      88.34  92.1300
# 3       80.78      92.20  91.5375
# 164     83.32      93.94  91.3075
# ...

# %%
df.sample(frac=0.5)
df.head(10)
# Out:
#       id               name                          email  Exams  Tests  \
# 203  204     Alysia Drummer            adrummer5n@ucoz.com  93.24  88.74
# 3      4      Kerri Chitson   kchitson3@huffingtonpost.com  94.64  98.53
# 164  165        Barry Simla            bsimla4k@dyndns.org  97.14  90.83
# 18    19    Jarrod Lashford           jlashfordi@wufoo.com  98.23  89.46
# 142  143    Guillaume Slate              gslate3y@jugem.jp  86.76  94.50
# 157  158     Matilde Burden  mburden4d@creativecommons.org  95.49  77.40
# 188  189    Aristotle Petel          apetel58@hubpages.com  74.74  94.60
# 66    67      Lazaro Hought        lhought1u@tuttocitta.it  92.14  98.79
# 244  245  Chauncey Parysiak   cparysiak6s@businesswire.com  98.88  78.40
# 206  207      Fianna Chance      fchance5q@theguardian.com  96.02  96.06
#
#      Projects  Home Work  Average
# 203     98.20      88.34  92.1300
# 3       80.78      92.20  91.5375
# 164     83.32      93.94  91.3075
# ...

# %%
df.sample(n=10)
# Out:
#       id               name                         email  Exams  Tests  \
# 164  165        Barry Simla           bsimla4k@dyndns.org  97.14  90.83
# 65    66    Ginni Philliphs  gphilliphs1t@hugedomains.com  73.43  65.25
# 158  159         De Roskams          droskams4e@ameblo.jp  75.29  92.96
# 46    47   Tiertza Trundler    ttrundler1a@soundcloud.com  62.35  95.61
# 248  249        Karlen Pook   kpook6w@constantcontact.com  79.63  61.14
# 163  164    Annnora Szymoni            aszymoni4j@msu.edu  77.50  89.34
# 98    99      Bert Goolding         bgoolding2q@opera.com  92.46  77.73
# 91    92     Krystyna Staff   kstaff2j@huffingtonpost.com  65.46  80.20
# 152  153  Bernardo Hawkyens        bhawkyens48@sphinn.com  66.27  97.52
# 247  248     Silvanus Rehor          srehor6v@behance.net  96.17  78.05
#
#      Projects  Home Work  Average
# 164     83.32      93.94  91.3075
# 65      96.58      61.99  74.3125
# 158     86.47      75.32  82.5100
# 46      71.49      77.07  76.6300
# ...

# %%
def medianAverage():
    median = df.Average.median()
    return median
medianAverage()
# Out:
# 79.66413

# %%
def medianEverything():
    exams = df['Exams'].median()
    tests = df['Tests'].median()
    projects = df['Projects'].median()
    homework = df['Home Work'].median()
    return ("Exams {}, Tests {}, Projects {}, Home Work {}".format(exams, tests, projects, homework))
medianEverything()
# Out:
# 'Exams 79.515, Tests 79.985, Projects 79.94, Home Work 78.58500000000001'

# %%
def minEverything():
    exams = df['Exams'].min()
    tests = df['Tests'].min()
    projects = df['Projects'].min()
    homework = df['Home Work'].min()
    return ("Exams {}, Tests {}, Projects {}, Home Work {}".format(exams, tests, projects, homework))
minEverything()
# Out:
# 'Exams 60.09, Tests 60.5, Projects 60.22, Home Work 60.05'

# %%
def maxEverything():
    exams = df['Exams'].max()
    tests = df['Tests'].max()
    projects = df['Projects'].max()
    homework = df['Home Work'].max()
    return ("Exams {}, Tests {}, Projects {}, Home Work {}".format(exams, tests, projects, homework))
maxEverything()
# Out:
# 'Exams 99.94, Tests 99.73, Projects 99.66, Home Work 99.93'
